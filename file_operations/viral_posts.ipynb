# %%
from csv import DictReader
fr=open("Cleaned_Viral_Social_Media_Trends.csv")
posts=list(DictReader(fr))

# %%
unique_platforms={p['Platform'] for p in posts}
unique_platforms
# Out:
# {'Instagram', 'TikTok', 'Twitter', 'YouTube'}

# %% [markdown]
# LEVEL 1

# %%
post_id=[p['Post_ID'] for p in posts]
post_id
# Out:
# ['Post_1',
#  'Post_2',
#  'Post_3',
#  'Post_4',
#  'Post_5',
#  'Post_6',
#  'Post_7',
#  'Post_8',
#  'Post_9',
#  'Post_10',
#  'Post_11',
#  'Post_12',
#  'Post_13',
#  'Post_14',
#  'Post_15',
#  'Post_16',
#  'Post_17',
#  'Post_18',
#  'Post_19',
#  'Post_20',
#  'Post_21',
#  'Post_22',
#  'Post_23',
#  'Post_24',
#  'Post_25',
#  'Post_26',
#  'Post_27',
#  'Post_28',
#  'Post_29',
#  'Post_30',
#  'Post_31',
#  'Post_32',
#  'Post_33',
#  'Post_34',
#  'Post_35',
#  'Post_36',
#  'Post_37',
#  'Post_38',
#  'Post_39',
#  'Post_40',
#  'Post_41',
#  'Post_42',
#  'Post_43',
#  'Post_44',
#  'Post_45',
#  'Post_46',
#  'Post_47',
#  'Post_48',
#  'Post_49',
#  'Post_50',
#  'Post_51',
#  'Post_52',
#  'Post_53',
#  'Post_54',
#  'Post_55',
#  'Post_56',
#  'Post_57',
#  'Post_58',
#  'Post_59',
#  'Post_60',
#  'Post_61',
#  'Post_62',
#  'Post_63',
#  'Post_64',
#  'Post_65',
#  'Post_66',
#  'Post_67',
#  'Post_68',
#  'Post_69',
#  'Post_70',
#  'Post_71',
#  'Post_72',
# ...

# %%
platform=[p['Platform'] for p in posts]
platform
# Out:
# ['TikTok',
#  'Instagram',
#  'Twitter',
#  'YouTube',
#  'TikTok',
#  'Instagram',
#  'YouTube',
#  'YouTube',
#  'Twitter',
#  'TikTok',
#  'Instagram',
#  'Twitter',
#  'YouTube',
#  'YouTube',
#  'Twitter',
#  'YouTube',
#  'Twitter',
#  'TikTok',
#  'TikTok',
#  'YouTube',
#  'Twitter',
#  'TikTok',
#  'YouTube',
#  'Twitter',
#  'YouTube',
#  'YouTube',
#  'Instagram',
#  'YouTube',
#  'Instagram',
#  'YouTube',
#  'Instagram',
#  'Twitter',
#  'YouTube',
#  'YouTube',
#  'YouTube',
#  'TikTok',
#  'Instagram',
#  'Instagram',
#  'TikTok',
#  'Twitter',
#  'Twitter',
#  'YouTube',
#  'Twitter',
#  'YouTube',
#  'Twitter',
#  'Instagram',
#  'Instagram',
#  'Instagram',
#  'Twitter',
#  'Instagram',
#  'YouTube',
#  'YouTube',
#  'YouTube',
#  'Twitter',
#  'Twitter',
#  'YouTube',
#  'Instagram',
#  'Twitter',
#  'YouTube',
#  'Twitter',
#  'TikTok',
#  'YouTube',
#  'TikTok',
#  'Instagram',
#  'YouTube',
#  'TikTok',
#  'YouTube',
#  'Twitter',
#  'Twitter',
#  'YouTube',
# ...

# %%
Region=[p['Region'] for p in posts]
Region
# Out:
# ['UK',
#  'India',
#  'Brazil',
#  'Australia',
#  'Brazil',
#  'Australia',
#  'Japan',
#  'UK',
#  'India',
#  'India',
#  'Germany',
#  'Australia',
#  'Canada',
#  'Japan',
#  'Germany',
#  'Canada',
#  'UK',
#  'UK',
#  'USA',
#  'UK',
#  'Brazil',
#  'USA',
#  'Brazil',
#  'Japan',
#  'Germany',
#  'Brazil',
#  'India',
#  'Canada',
#  'Canada',
#  'Japan',
#  'Australia',
#  'USA',
#  'USA',
#  'Australia',
#  'UK',
#  'Japan',
#  'Germany',
#  'India',
#  'USA',
#  'USA',
#  'India',
#  'Australia',
#  'Brazil',
#  'Brazil',
#  'Germany',
#  'Brazil',
#  'Japan',
#  'India',
#  'USA',
#  'Japan',
#  'Australia',
#  'Canada',
#  'Japan',
#  'Canada',
#  'USA',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Germany',
#  'UK',
#  'USA',
#  'Australia',
#  'India',
#  'Canada',
#  'Canada',
#  'Japan',
#  'Brazil',
#  'Japan',
#  'USA',
#  'Australia',
#  'Japan',
#  'Australia',
#  'Germany',
#  'India',
#  'USA',
#  'India',
#  'India',
#  'Australia',
#  'USA',
# ...

# %%
Views=[p['Views'] for p in posts]
Views
# Out:
# ['4163464',
#  '4155940',
#  '3666211',
#  '917951',
#  '64866',
#  '1323566',
#  '627233',
#  '2066886',
#  '2169523',
#  '3898384',
#  '4070332',
#  '4585669',
#  '4105651',
#  '1633015',
#  '2471790',
#  '3079923',
#  '294870',
#  '2051091',
#  '3461154',
#  '3143932',
#  '14095',
#  '3924406',
#  '599766',
#  '4357851',
#  '731492',
#  '4910814',
#  '4369260',
#  '1874437',
#  '1653907',
#  '4683280',
#  '1365655',
#  '2342195',
#  '4977438',
#  '3005703',
#  '936390',
#  '1855796',
#  '48908',
#  '1367820',
#  '4499253',
#  '4510477',
#  '4380015',
#  '943395',
#  '3961278',
#  '4080112',
#  '3934142',
#  '272327',
#  '1600237',
#  '2212857',
#  '4711157',
#  '2747788',
#  '2081426',
#  '2258494',
#  '1357850',
#  '392337',
#  '4006009',
#  '3934991',
#  '2824818',
#  '197986',
#  '2291491',
#  '3525573',
#  '866896',
#  '4104535',
#  '2601441',
#  '1142030',
#  '2969591',
#  '855465',
#  '4453459',
#  '1059696',
#  '581577',
#  '4226427',
#  '485214',
#  '1419701',
# ...

# %%
Likes_comments=[(p['Likes'],p['Comments']) for p in posts]
Likes_comments
# Out:
# [('339431', '19346'),
#  ('215240', '27239'),
#  ('327143', '36223'),
#  ('127125', '36806'),
#  ('171361', '6376'),
#  ('136282', '47129'),
#  ('84121', '32648'),
#  ('317502', '33638'),
#  ('496078', '30174'),
#  ('8634', '42700'),
#  ('379894', '25242'),
#  ('465871', '8999'),
#  ('195560', '49089'),
#  ('312907', '30725'),
#  ('370802', '17081'),
#  ('124237', '26702'),
#  ('213142', '20767'),
#  ('24472', '41737'),
#  ('165335', '19505'),
#  ('298685', '37162'),
#  ('268310', '16968'),
#  ('35376', '3949'),
#  ('223690', '10538'),
#  ('449803', '28280'),
#  ('474649', '3654'),
#  ('197287', '14896'),
#  ('212278', '18172'),
#  ('322601', '48768'),
#  ('91836', '2823'),
#  ('311330', '5110'),
#  ('156164', '18303'),
#  ('91944', '44440'),
#  ('8731', '46045'),
#  ('16688', '15891'),
#  ('368646', '2016'),
#  ('158156', '20518'),
#  ('205884', '14618'),
#  ('10794', '36639'),
#  ('469481', '41549'),
#  ('274631', '13932'),
#  ('355402', '42729'),
#  ('402996', '11999'),
# ...

# %%
posts
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_4',
#   'Post_Date': '2022-12-05',
#   'Platform': 'YouTube',
#   'Hashtag': '#Education',
# ...

# %%
len(posts)
# Out:
# 5000

# %%
india=[p for p in posts if p['Region']=='India']
len(india)
# Out:
# 617

# %%
Brazil=[p for p in posts if p['Region']=='Brazil']
len(Brazil)
# Out:
# 641

# %%
UK=[p for p in posts if p['Region']=='UK']
len(UK)
# Out:
# 647

# %%
instagram=[p for p in posts if p['Platform']=='Instagram']
len(instagram)
# Out:
# 1212

# %%
TikTok=[p for p in posts if p['Platform']=='TikTok']
len(TikTok)
# Out:
# 1260

# %%
Video=[p for p in posts if p['Content_Type']=='Video']
len(Video)
# Out:
# 828

# %%
High=[p for p in posts if p['Engagement_Level']=='High']
len(High)
# Out:
# 1673

# %%
total_views = sum(int(p['Views']) for p in posts)
total_views
# Out:
# 12470332220

# %%
total_Likes = sum(int(p['Likes']) for p in posts)
total_Likes
# Out:
# 1257375149

# %%
total_Shares = sum(int(p['Shares']) for p in posts)
total_Shares
# Out:
# 252597810

# %%
total_Comments = sum(int(p['Comments']) for p in posts)
total_Comments
# Out:
# 124441969

# %%
highest_views=max(posts,key=lambda d:int(d['Views']))
highest_views
# Out:
# {'Post_ID': 'Post_676',
#  'Post_Date': '2023-10-02',
#  'Platform': 'YouTube',
#  'Hashtag': '#Dance',
#  'Content_Type': 'Live Stream',
#  'Region': 'Canada',
#  'Views': '4999430',
#  'Likes': '419635',
#  'Shares': '51709',
#  'Comments': '19836',
#  'Engagement_Level': 'Low'}

# %%
lowest_views=min(posts,key=lambda d:int(d['Views']))
lowest_views
# Out:
# {'Post_ID': 'Post_4827',
#  'Post_Date': '2023-09-03',
#  'Platform': 'TikTok',
#  'Hashtag': '#Viral',
#  'Content_Type': 'Shorts',
#  'Region': 'USA',
#  'Views': '1266',
#  'Likes': '318849',
#  'Shares': '1715',
#  'Comments': '36121',
#  'Engagement_Level': 'High'}

# %%
india_posts=[p for p in posts if p['Region']=='India']
india_posts
# Out:
# [{'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_9',
#   'Post_Date': '2022-09-01',
#   'Platform': 'Twitter',
#   'Hashtag': '#Education',
#   'Content_Type': 'Live Stream',
#   'Region': 'India',
#   'Views': '2169523',
#   'Likes': '496078',
#   'Shares': '96041',
#   'Comments': '30174',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_10',
#   'Post_Date': '2023-01-01',
#   'Platform': 'TikTok',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '3898384',
#   'Likes': '8634',
#   'Shares': '69378',
#   'Comments': '42700',
#   'Engagement_Level': 'Low'},
#  {'Post_ID': 'Post_27',
#   'Post_Date': '2023-05-14',
#   'Platform': 'Instagram',
#   'Hashtag': '#Gaming',
# ...

# %%
insta_posts=[p for p in posts if p['Platform']=='Instagram']
insta_posts
# Out:
# [{'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Shorts',
#   'Region': 'Australia',
#   'Views': '1323566',
#   'Likes': '136282',
#   'Shares': '86979',
#   'Comments': '47129',
#   'Engagement_Level': 'Low'},
#  {'Post_ID': 'Post_11',
#   'Post_Date': '2023-08-09',
#   'Platform': 'Instagram',
#   'Hashtag': '#Comedy',
#   'Content_Type': 'Live Stream',
#   'Region': 'Germany',
#   'Views': '4070332',
#   'Likes': '379894',
#   'Shares': '46012',
#   'Comments': '25242',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_27',
#   'Post_Date': '2023-05-14',
#   'Platform': 'Instagram',
# ...

# %%
high_eng_posts=[p for p in posts if p['Engagement_Level']=='High']
high_eng_posts
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_8',
#   'Post_Date': '2022-01-14',
#   'Platform': 'YouTube',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Shorts',
#   'Region': 'UK',
#   'Views': '2066886',
#   'Likes': '317502',
#   'Shares': '45222',
#   'Comments': '33638',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_11',
#   'Post_Date': '2023-08-09',
#   'Platform': 'Instagram',
#   'Hashtag': '#Comedy',
#   'Content_Type': 'Live Stream',
#   'Region': 'Germany',
#   'Views': '4070332',
#   'Likes': '379894',
#   'Shares': '46012',
#   'Comments': '25242',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_13',
#   'Post_Date': '2022-03-16',
#   'Platform': 'YouTube',
#   'Hashtag': '#Viral',
# ...

# %%
v=[p for p in posts if int(p['Views'])>1000000]
v
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
#   'Hashtag': '#Challenge',
# ...

# %%
l=[p for p in posts if int(p['Likes'])>100000]
l
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_4',
#   'Post_Date': '2022-12-05',
#   'Platform': 'YouTube',
#   'Hashtag': '#Education',
# ...

# %%
s=[p for p in posts if int(p['Shares'])>50000]
s
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_5',
#   'Post_Date': '2023-03-23',
#   'Platform': 'TikTok',
#   'Hashtag': '#Dance',
#   'Content_Type': 'Post',
#   'Region': 'Brazil',
#   'Views': '64866',
#   'Likes': '171361',
#   'Shares': '69581',
#   'Comments': '6376',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
#   'Hashtag': '#Challenge',
# ...

# %%
c=[p for p in posts if int(p['Comments'])>20000]
c
# Out:
# [{'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_4',
#   'Post_Date': '2022-12-05',
#   'Platform': 'YouTube',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'Australia',
#   'Views': '917951',
#   'Likes': '127125',
#   'Shares': '11687',
#   'Comments': '36806',
#   'Engagement_Level': 'Low'},
#  {'Post_ID': 'Post_6',
#   'Post_Date': '2022-11-23',
#   'Platform': 'Instagram',
# ...

# %%
v=[p for p in posts if int(p['Views'])>1000000]
len(v)
# Out:
# 3971

# %%
india_posts=[p for p in posts if p['Region']=='India']
india_views= sum(int(i['Views']) for i in india_posts)
india_views
# Out:
# 1513372283

# %%
insta_posts=[p for p in posts if p['Platform']=='Instagram']
insta_likes=sum(int(i['Likes']) for i in insta_posts)
insta_likes
# Out:
# 311627280

# %%
tiktok_posts=[p for p in posts if p['Platform']=='TikTok']
tiktok_shares=sum(int(t['Shares']) for t in tiktok_posts)
tiktok_shares
# Out:
# 64850003

# %%
Brazil=[p for p in posts if p['Region']=='Brazil']
brazil_comments=sum(int(b['Comments']) for b in Brazil)
brazil_comments
# Out:
# 15867659

# %%
total_views = sum(int(p['Views']) for p in posts)
avg_views=total_views/len(Views)
avg_views
# Out:
# 2494066.444

# %%
avg_likes=total_Likes/len(posts)
avg_likes
# Out:
# 251475.0298

# %%
avg_shares=total_Shares/len(posts)
avg_shares
# Out:
# 50519.562

# %%
avg_comments=total_Comments/len(posts)
avg_comments
# Out:
# 24888.3938

# %%
highest_like=max(posts,key=lambda d:int(d['Likes']))
highest_like
# Out:
# {'Post_ID': 'Post_3134',
#  'Post_Date': '2023-08-06',
#  'Platform': 'TikTok',
#  'Hashtag': '#Fitness',
#  'Content_Type': 'Shorts',
#  'Region': 'Germany',
#  'Views': '2973845',
#  'Likes': '499922',
#  'Shares': '38576',
#  'Comments': '19020',
#  'Engagement_Level': 'High'}

# %%
highest_share=max(posts,key=lambda d:int(d['Shares']))
highest_share
# Out:
# {'Post_ID': 'Post_792',
#  'Post_Date': '2023-04-30',
#  'Platform': 'TikTok',
#  'Hashtag': '#Music',
#  'Content_Type': 'Tweet',
#  'Region': 'Canada',
#  'Views': '149515',
#  'Likes': '62294',
#  'Shares': '99978',
#  'Comments': '25533',
#  'Engagement_Level': 'Low'}

# %%
highest_comment=max(posts,key=lambda d:int(d['Comments']))
highest_comment
# Out:
# {'Post_ID': 'Post_1668',
#  'Post_Date': '2022-08-02',
#  'Platform': 'TikTok',
#  'Hashtag': '#Education',
#  'Content_Type': 'Shorts',
#  'Region': 'Canada',
#  'Views': '295569',
#  'Likes': '56857',
#  'Shares': '20351',
#  'Comments': '49993',
#  'Engagement_Level': 'Medium'}

# %%
lowest_like=min(posts,key=lambda d:int(d['Likes']))
lowest_like
# Out:
# {'Post_ID': 'Post_1546',
#  'Post_Date': '2023-07-21',
#  'Platform': 'YouTube',
#  'Hashtag': '#Tech',
#  'Content_Type': 'Reel',
#  'Region': 'UK',
#  'Views': '3101726',
#  'Likes': '490',
#  'Shares': '80829',
#  'Comments': '593',
#  'Engagement_Level': 'High'}

# %%
po=[p for p in posts if int(p['Views'])>1000000 and int(p['Likes'])>100000]
len(po)
# Out:
# 3183

# %%
post_filter=[p for p in posts if int(p['Views'])>2000000 and int(p['Likes'])>200000]
post_filter
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_8',
#   'Post_Date': '2022-01-14',
#   'Platform': 'YouTube',
#   'Hashtag': '#Gaming',
# ...

# %%
insta_high=[p for p in posts if p['Platform']=='Instagram' and p['Engagement_Level']=='High']
insta_high
# Out:
# [{'Post_ID': 'Post_11',
#   'Post_Date': '2023-08-09',
#   'Platform': 'Instagram',
#   'Hashtag': '#Comedy',
#   'Content_Type': 'Live Stream',
#   'Region': 'Germany',
#   'Views': '4070332',
#   'Likes': '379894',
#   'Shares': '46012',
#   'Comments': '25242',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_46',
#   'Post_Date': '2023-12-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Tweet',
#   'Region': 'Brazil',
#   'Views': '272327',
#   'Likes': '274271',
#   'Shares': '56073',
#   'Comments': '17526',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_64',
#   'Post_Date': '2023-12-05',
#   'Platform': 'Instagram',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Shorts',
#   'Region': 'Canada',
#   'Views': '1142030',
#   'Likes': '212596',
#   'Shares': '72334',
#   'Comments': '18',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_76',
#   'Post_Date': '2023-05-12',
#   'Platform': 'Instagram',
#   'Hashtag': '#Dance',
# ...

# %%
india_video=[p for p in posts if p['Region']=='India' and p['Content_Type']=='Video']
india_video
# Out:
# [{'Post_ID': 'Post_27',
#   'Post_Date': '2023-05-14',
#   'Platform': 'Instagram',
#   'Hashtag': '#Gaming',
#   'Content_Type': 'Video',
#   'Region': 'India',
#   'Views': '4369260',
#   'Likes': '212278',
#   'Shares': '21264',
#   'Comments': '18172',
#   'Engagement_Level': 'Low'},
#  {'Post_ID': 'Post_38',
#   'Post_Date': '2023-07-15',
#   'Platform': 'Instagram',
#   'Hashtag': '#Dance',
#   'Content_Type': 'Video',
#   'Region': 'India',
#   'Views': '1367820',
#   'Likes': '10794',
#   'Shares': '7617',
#   'Comments': '36639',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_132',
#   'Post_Date': '2023-02-24',
#   'Platform': 'YouTube',
#   'Hashtag': '#Education',
#   'Content_Type': 'Video',
#   'Region': 'India',
#   'Views': '3487375',
#   'Likes': '107303',
#   'Shares': '83451',
#   'Comments': '45313',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_139',
#   'Post_Date': '2023-04-16',
#   'Platform': 'Instagram',
#   'Hashtag': '#Music',
# ...

# %%
high_eng_tot_views=sum(int(p['Views']) for p in posts if p['Engagement_Level']=='High')
high_eng_tot_views
# Out:
# 4093949112

# %%
platform_summary={}
for p in posts:
    platform=p['Platform']
    view=int(p['Views'])
    if platform in platform_summary:
        platform_summary[platform]+=view
    else:
        platform_summary[platform]=view
platform_summary
# Out:
# {'TikTok': 3168919406,
#  'Instagram': 2913744812,
#  'Twitter': 3017229522,
#  'YouTube': 3370438480}

# %%
max(platform_summary,key=platform_summary.get)
# Out:
# 'YouTube'

# %%
plat_like_summary={}
for p in posts:
    platform=p['Platform']
    likes=int(p['Likes'])
    if platform in plat_like_summary:
        plat_like_summary[platform]+=likes
    else:
        plat_like_summary[platform]=likes

plat_like_summary
# Out:
# {'TikTok': 307700467,
#  'Instagram': 311627280,
#  'Twitter': 296039663,
#  'YouTube': 342007739}

# %%
max(plat_like_summary,key=plat_like_summary.get)
# Out:
# 'YouTube'

# %%
plat_share_summary={}
for p in posts:
    platform=p['Platform']
    shares=int(p['Shares'])
    if platform in plat_share_summary:
        plat_share_summary[platform]+=shares
    else:
        plat_share_summary[platform]=shares

plat_share_summary
# Out:
# {'TikTok': 64850003,
#  'Instagram': 60976822,
#  'Twitter': 60474212,
#  'YouTube': 66296773}

# %%
max(plat_share_summary,key=plat_share_summary.get)
# Out:
# 'YouTube'

# %%
region_view_summary={}
for p in posts:
    region=p['Region']
    views=int(p['Views'])
    if region in region_view_summary:
        region_view_summary[region]+=views
    else:
        region_view_summary[region]=views

region_view_summary
# Out:
# {'UK': 1619027523,
#  'India': 1513372283,
#  'Brazil': 1639502227,
#  'Australia': 1462197447,
#  'Japan': 1430193320,
#  'Germany': 1441300699,
#  'Canada': 1607786982,
#  'USA': 1756951739}

# %%
max(region_view_summary,key=region_view_summary.get)
# Out:
# 'USA'

# %%
region_like_summary={}
for p in posts:
    region=p['Region']
    likes=int(p['Likes'])
    if region in region_like_summary:
        region_like_summary[region]+=likes
    else:
        region_like_summary[region]=likes

region_like_summary
# Out:
# {'UK': 164351194,
#  'India': 154827086,
#  'Brazil': 158980662,
#  'Australia': 153140456,
#  'Japan': 151895861,
#  'Germany': 138283644,
#  'Canada': 168585301,
#  'USA': 167310945}

# %%
#region with highest total likes
max(region_like_summary,key=region_like_summary.get)
# Out:
# 'Canada'

# %%
hashtag_count={}
for p in posts:
    hashtag=p['Hashtag']
    if hashtag in hashtag_count:
        hashtag_count[hashtag]+=1
    else:
        hashtag_count[hashtag]=1

hashtag_count
# Out:
# {'#Challenge': 507,
#  '#Education': 525,
#  '#Dance': 496,
#  '#Comedy': 505,
#  '#Gaming': 479,
#  '#Music': 493,
#  '#Viral': 481,
#  '#Fitness': 536,
#  '#Tech': 491,
#  '#Fashion': 487}

# %%
max(hashtag_count,key=hashtag_count.get)
# Out:
# '#Fitness'

# %%
content_type_count={}
for p in posts:
    content_type=p['Content_Type']
    if content_type in content_type_count:
        content_type_count[content_type]+=1
    else:
        content_type_count[content_type]=1

content_type_count
# Out:
# {'Video': 828,
#  'Shorts': 787,
#  'Post': 853,
#  'Tweet': 836,
#  'Live Stream': 855,
#  'Reel': 841}

# %%
max(content_type_count,key=content_type_count.get)
# Out:
# 'Live Stream'

# %%
engagement_level_count={}
for p in posts:
    engagement_level=p['Engagement_Level']
    if engagement_level in engagement_level_count:
        engagement_level_count[engagement_level]+=1
    else:
        engagement_level_count[engagement_level]=1

engagement_level_count
# Out:
# {'High': 1673, 'Medium': 1598, 'Low': 1729}

# %%
max(engagement_level_count,key=engagement_level_count.get)
# Out:
# 'Low'

# %%
engagement_score={}
for p in posts:
    post_id=p['Post_ID']
    engagement_score[post_id]=int(p['Likes'])+int(p['Shares'])+int(p['Comments'])

engagement_score
# Out:
# {'Post_1': 411912,
#  'Post_2': 308339,
#  'Post_3': 402789,
#  'Post_4': 175618,
#  'Post_5': 247318,
#  'Post_6': 270390,
#  'Post_7': 214742,
#  'Post_8': 396362,
#  'Post_9': 622293,
#  'Post_10': 120712,
#  'Post_11': 451148,
#  'Post_12': 543953,
#  'Post_13': 282276,
#  'Post_14': 389406,
#  'Post_15': 441993,
#  'Post_16': 195001,
#  'Post_17': 254260,
#  'Post_18': 120913,
#  'Post_19': 234917,
#  'Post_20': 420567,
#  'Post_21': 375773,
#  'Post_22': 112157,
#  'Post_23': 256759,
#  'Post_24': 541521,
#  'Post_25': 576680,
#  'Post_26': 265401,
#  'Post_27': 251714,
#  'Post_28': 407040,
#  'Post_29': 172029,
#  'Post_30': 319797,
#  'Post_31': 259397,
#  'Post_32': 225962,
#  'Post_33': 59276,
#  'Post_34': 110549,
#  'Post_35': 462864,
#  'Post_36': 185097,
#  'Post_37': 257758,
#  'Post_38': 55050,
#  'Post_39': 600613,
#  'Post_40': 370706,
#  'Post_41': 439991,
#  'Post_42': 433656,
#  'Post_43': 166680,
#  'Post_44': 230942,
#  'Post_45': 450024,
# ...

# %%
max(engagement_score,key=engagement_score.get)
# Out:
# 'Post_2908'

# %%
min(engagement_score,key=engagement_score.get)
# Out:
# 'Post_3692'

# %%
like_to_view_percentage={}
for p in posts:
    post_id=p['Post_ID']
    like_to_view_percentage[post_id]=(int(p['Likes'])/int(p['Views']))*100

like_to_view_percentage
# Out:
# {'Post_1': 8.152610422475131,
#  'Post_2': 5.179093057166369,
#  'Post_3': 8.92319072742949,
#  'Post_4': 13.848778420634652,
#  'Post_5': 264.1769185705917,
#  'Post_6': 10.29657757905537,
#  'Post_7': 13.411443594326192,
#  'Post_8': 15.361369712698233,
#  'Post_9': 22.865763580289308,
#  'Post_10': 0.22147638611280984,
#  'Post_11': 9.333243578165122,
#  'Post_12': 10.159281012214358,
#  'Post_13': 4.763191026222151,
#  'Post_14': 19.16130592799209,
#  'Post_15': 15.001355293127652,
#  'Post_16': 4.033769675410716,
#  'Post_17': 72.2833791162207,
#  'Post_18': 1.1931211243187163,
#  'Post_19': 4.7768749960273365,
#  'Post_20': 9.500364511700635,
#  'Post_21': 1903.5828307910606,
#  'Post_22': 0.9014357841670815,
#  'Post_23': 37.296212189420544,
#  'Post_24': 10.321670015794481,
#  'Post_25': 64.88779098062591,
#  'Post_26': 4.017399152156853,
#  'Post_27': 4.858442848445732,
#  'Post_28': 17.210554422474587,
#  'Post_29': 5.552670131996539,
#  'Post_30': 6.6476913616098114,
# ...

# %%
max(like_to_view_percentage,key=like_to_view_percentage.get)
# Out:
# 'Post_4827'

# %%
share_to_view_percentage={}
for p in posts:
    post_id=p['Post_ID']
    share_to_view_percentage[post_id]=(int(p['Shares'])/int(p['Views']))*100

share_to_view_percentage
# Out:
# {'Post_1': 1.2762209544744472,
#  'Post_2': 1.5847197024018636,
#  'Post_3': 1.0753063585265552,
#  'Post_4': 1.2731616393467626,
#  'Post_5': 107.26883112878858,
#  'Post_6': 6.571564999403128,
#  'Post_7': 15.619873316614399,
#  'Post_8': 2.1879290875258723,
#  'Post_9': 4.426825620193932,
#  'Post_10': 1.7796604952205834,
#  'Post_11': 1.1304237590447166,
#  'Post_12': 1.5064977432954711,
#  'Post_13': 0.9164685454267789,
#  'Post_14': 2.8030361019341523,
#  'Post_15': 2.1891018249932235,
#  'Post_16': 1.4306201810889427,
#  'Post_17': 6.901685488520365,
#  'Post_18': 2.6670684040834853,
#  'Post_19': 1.446829583427955,
#  'Post_20': 2.694714771184618,
#  'Post_21': 642.0361830436325,
#  'Post_22': 1.855873220049098,
#  'Post_23': 3.756631753050356,
#  'Post_24': 1.4557175084691973,
#  'Post_25': 13.448814204393214,
#  'Post_26': 1.0836899951820613,
#  'Post_27': 0.4866728004284478,
#  'Post_28': 1.9030247482310687,
#  'Post_29': 4.678013939115077,
# ...

# %%
max(share_to_view_percentage,key=share_to_view_percentage.get)
# Out:
# 'Post_1541'

# %%
likes_gt_than_shares=[p for p in posts if int(p['Likes'])>int(p['Shares'])]
likes_gt_than_shares
# Out:
# [{'Post_ID': 'Post_1',
#   'Post_Date': '2022-01-13',
#   'Platform': 'TikTok',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'UK',
#   'Views': '4163464',
#   'Likes': '339431',
#   'Shares': '53135',
#   'Comments': '19346',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_2',
#   'Post_Date': '2022-05-13',
#   'Platform': 'Instagram',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'India',
#   'Views': '4155940',
#   'Likes': '215240',
#   'Shares': '65860',
#   'Comments': '27239',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_3',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Challenge',
#   'Content_Type': 'Video',
#   'Region': 'Brazil',
#   'Views': '3666211',
#   'Likes': '327143',
#   'Shares': '39423',
#   'Comments': '36223',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_4',
#   'Post_Date': '2022-12-05',
#   'Platform': 'YouTube',
#   'Hashtag': '#Education',
# ...

# %%
pos=[p for p in posts if int(p['Likes'])+int(p['Shares'])+int(p['Comments'])>500000]
pos
# Out:
# [{'Post_ID': 'Post_9',
#   'Post_Date': '2022-09-01',
#   'Platform': 'Twitter',
#   'Hashtag': '#Education',
#   'Content_Type': 'Live Stream',
#   'Region': 'India',
#   'Views': '2169523',
#   'Likes': '496078',
#   'Shares': '96041',
#   'Comments': '30174',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_12',
#   'Post_Date': '2023-02-26',
#   'Platform': 'Twitter',
#   'Hashtag': '#Music',
#   'Content_Type': 'Reel',
#   'Region': 'Australia',
#   'Views': '4585669',
#   'Likes': '465871',
#   'Shares': '69083',
#   'Comments': '8999',
#   'Engagement_Level': 'Medium'},
#  {'Post_ID': 'Post_24',
#   'Post_Date': '2022-01-07',
#   'Platform': 'Twitter',
#   'Hashtag': '#Education',
#   'Content_Type': 'Shorts',
#   'Region': 'Japan',
#   'Views': '4357851',
#   'Likes': '449803',
#   'Shares': '63438',
#   'Comments': '28280',
#   'Engagement_Level': 'High'},
#  {'Post_ID': 'Post_25',
#   'Post_Date': '2023-07-19',
#   'Platform': 'YouTube',
#   'Hashtag': '#Dance',
# ...

# %%
platform_views={}
for p in posts:
    platform=p['Platform']
    views=int(p['Views'])
    if platform in platform_views:
        platform_views[platform].append(views)
    else:
        platform_views[platform]=[views]

platform_views
# Out:
# {'TikTok': [4163464,
#   64866,
#   3898384,
#   2051091,
#   3461154,
#   3924406,
#   1855796,
#   4499253,
#   866896,
#   2601441,
#   855465,
#   4378457,
#   3647159,
#   907386,
#   2141884,
#   128472,
#   1347102,
#   92085,
#   3843536,
#   2249678,
#   4655757,
#   1402998,
#   4600976,
#   1838563,
#   1772623,
#   3924183,
#   3859007,
#   4828597,
#   3418884,
#   707841,
#   1851460,
#   1089083,
#   682046,
#   636824,
#   4179125,
#   3251679,
#   1246500,
#   102418,
#   1551922,
#   2784320,
#   798887,
#   496652,
#   479620,
#   2488223,
#   2440215,
#   3982001,
#   2651939,
#   1580449,
#   4497673,
#   2177828,
#   4096796,
#   2095875,
#   1111002,
#   1556267,
#   1828433,
#   3290858,
#   506215,
#   1450112,
#   3714148,
#   1612356,
#   1483481,
#   1035819,
#   3949831,
#   4820393,
#   864256,
#   4412697,
#   3763770,
#   2337694,
#   1423060,
#   245443,
#   2243003,
#   1357286,
#   436487,
#   1070510,
#   3369227,
#   2580238,
#   1094116,
# ...

# %%
platform_avg={k:sum(v)/len(v) for k,v in platform_views.items()}
platform_avg
# Out:
# {'TikTok': 2515015.4015873014,
#  'Instagram': 2404079.8778877887,
#  'Twitter': 2506004.5863787374,
#  'YouTube': 2545648.398791541}

# %%
max(platform_avg,key=platform_avg.get)
# Out:
# 'YouTube'

# %%
region_likes={}
for p in posts:
    region=p['Region']
    likes=int(p['Likes'])
    if region in region_likes:
        region_likes[region].append(likes)
    else:
        region_likes[region]=[likes]

region_avg_likes={k:sum(v)/len(v) for k,v in region_likes.items()}
region_avg_likes
# Out:
# {'UK': 254020.39258114374,
#  'India': 250935.3095623987,
#  'Brazil': 248019.7535101404,
#  'Australia': 254386.13953488372,
#  'Japan': 256580.8462837838,
#  'Germany': 244317.3922261484,
#  'Canada': 256208.6641337386,
#  'USA': 247135.81240768093}

# %%
max(region_avg_likes,key=region_avg_likes.get)
# Out:
# 'Japan'

# %%
enagagement_views={}
for p in posts:
    engagement_level=p['Engagement_Level']
    views=int(p['Views'])
    if engagement_level in enagagement_views:
        enagagement_views[engagement_level].append(views)
    else:
        enagagement_views[engagement_level]=[views]

enagagement_views_avg={k:sum(v)/len(v) for k,v in enagagement_views.items()}
enagagement_views_avg
# Out:
# {'High': 2447070.5989240883,
#  'Medium': 2529243.6157697123,
#  'Low': 2507028.230190862}

# %%
max(enagagement_views_avg,key=enagagement_views_avg.get)
# Out:
# 'Medium'
