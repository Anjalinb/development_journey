# %%
fr=open("movies.csv","r",encoding='utf-8')
movies=[]

for line in fr:
    line=line.rstrip("\n")
    id,title,language,year,run_time,rating,genre=line.split(",")
    movie_dict={
        "id":id,
        "title":title,
        "language":language,
        "year":year,
        "run_time":run_time,
        "rating":rating,
        
        "genre":genre
    }
    movies.append(movie_dict)
print(len(movies))
# Out:
# 39

# %%
#all titles
all_titles=[m['title'] for m in movies]
all_titles
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  '12 Angry Men',
#  "Schindler's List",
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  'Fight Club',
#  'Inception',
#  'Manichitrathazhu',
#  'Spirited Away',
#  'Seven Samurai',
#  'Interstellar',
#  'Parasite',
#  'Life Is Beautiful',
#  'City of God',
#  'Saving Private Ryan',
#  'Nayakan',
#  'The Green Mile',
#  'Intouchables',
#  'Cinema Paradiso',
#  'Whiplash',
#  'The Prestige',
#  'Gladiator',
#  'Kumbalangi Nights',
#  '3 Idiots',
#  'Dangal',
#  'Drishyam',
#  'Amélie',
#  "Pan's Labyrinth",
#  'Vikram Vedha',
#  'Oldboy',
#  'Lagaan',
#  'Anbe Sivam',
#  'Harakiri',
#  'A Separation',
#  'The Pianist',
#  'Rear Window',
#  'Psycho']
